# %%
import pandas as pd
var = pd.read_csv("Beast.csv")
var
# Out:
#     No.      Symbol                            Security  Today - Volume  \
# 0     1   ELECTHERM        Electrotherm (India) Limited          473907
# 1     2      NBIFIN  N. B. I Industrial Finance Company            5754
# 2     3     HINDCON           Hindcon chemicals Limited          304759
# 3     4  GKWLIMITED                         GKW Limited           21375
# 4     5  21STCENMGM    21st century Management Services          110375
# 5     6    ALPHAGEO            Alphageo (india) Limited               1
# 6     7    UNIENTER         Uniphos Enterprises Limited               1
# 7     8  JAGSNPHARM   Jagsonpal Pharmaceuticals Limited               1
# 8     9  SKMEGGPROD     SKM Egg Products Export (India)               1
# 9    10   SWELECTES      Swelect Energy Systems Limited               1
# 10   11   NAHARPOLY            Nahar Poly Films Limited               1
# 11   12  PODDARHOUS      Poddar Housing and Development               1
# ...
